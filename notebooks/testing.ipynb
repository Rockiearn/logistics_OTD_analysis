# %%
from analysis import get_dashboard_kpi
import pandas as pd

df = get_dashboard_kpi().iloc[0,1]
df
# Out:
# '4.3 %'

# %%
from analysis import get_cancellation_analysis
import pandas as pd

Shipping = get_cancellation_analysis()[0]

Shipping["Proportion"] = ((Shipping["Total_sales_lost"]/Shipping["Total_sales_lost"].sum()) * 100).round(2)

Shipping
# Out:
#     Shipping Mode  Total_contribution  Total_sales_lost  Proportion
# 0     First Class                1301         266301.19       16.96
# 1        Same Day                 444          87656.35        5.58
# 2    Second Class                1410         284783.25       18.14
# 3  Standard Class                4599         931564.54       59.32
